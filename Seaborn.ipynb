# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
notas = np.random.normal(loc=70, scale=20, size=100)

# %%
dados = pd.DataFrame({'Notas': notas})

# %%
dados

# %%
sns.kdeplot(data=dados['Notas'], fill=True)

# %%
altura = np.random.normal(loc=175, scale=10, size=100)

# %%
largura = np.random.normal(loc=70, scale=10, size=100)

# %%
dados_joint = pd.DataFrame({'Altura': altura, 'Largura': largura})

# %%
sns.jointplot(x='Altura', y='Largura', data=dados_joint, kind='kde', color='blue')

# %%
dados_vendas = dados_vendas = {
    'Jogos': ['CS:GO', 'No Mans Sky', 'Fallout', 'Resident Evil 7', 'Minecraft', 'Need For Speed'],
    'Vendas Jan': np.random.randint(low=100, high=1501, size=6),
    'Vendas Fev': np.round(np.random.normal( loc=700, scale=200, size=6)),
    'Vendas Mar': np.round(np.random.normal( loc=700, scale=200, size=6))
}

# %%
df_vendas = pd.DataFrame(dados_vendas)

# %%
sns.set_style('dark')

# %%
sns.barplot(x='Jogos', y='Vendas Jan', data=df_vendas)
# Out:
# <Axes: xlabel='Jogos', ylabel='Vendas Jan'>
