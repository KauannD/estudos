# %%
import numpy as pd
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier

# %%
iris = load_iris()

# %%
X = pd.DataFrame(iris.data, columns=iris.feature_names)
y = pd.Series(iris.target)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,  test_size=0.3, random_state=42)

# %%
modelo_gb = GradientBoostingClassifier()

# %%
modelo_gb.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
acuracia = modelo_gb.score(X_test, y_test)

# %%
print(f"Acuracia: {acuracia}")
# Out:
# Acuracia: 1.0

# %%
nova_flor = [3.0, 0.3, 1.0, 1.2]

# %%
previsao = modelo_gb.predict([nova_flor])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingClassifier was fitted with feature names
#   warnings.warn(

# %%
print("Especie provavel:", iris.target_names[previsao][0])
# Out:
# Especie provavel: versicolor

# %% [markdown]
# #AVALIANDO MODELO

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
comprimento = [round(random.uniform(0, 8), 1) for i in range(20)]
largura = [round(random.uniform(0, 8), 1) for i in range(20)]

# %%
comprimento

# %%
especies = ['setosa'] * 3 + ['versicolor'] * 4 + ['virginica'] * 13

# %%
df_fds = pd.DataFrame({'comprimento':comprimento, 'largura':largura, 'classe':especies})

# %%
modelo_KN = KNeighborsClassifier(n_neighbors=3)

# %%
X = df_fds[['comprimento', 'largura']]

# %%
y = df_fds['classe']

# %%
modelo_KN.fit(X, y)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
modelo_KN.predict(X)
# Out:
# array(['setosa', 'virginica', 'virginica', 'virginica', 'versicolor',
#        'versicolor', 'virginica', 'virginica', 'virginica', 'virginica',
#        'setosa', 'virginica', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'virginica', 'versicolor', 'virginica'],
#       dtype=object)

# %%
amostra = [[7.3,7.8]]
previsao = modelo_KN.predict(amostra)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
print(f'Provavel da classe: {previsao[0]}')
# Out:
# Provavel da classe: setosa

# %%
y_pred = modelo_KN.predict(X)

# %%
print('Acuracia', accuracy_score(y, y_pred))
print('Matriz confusion', confusion_matrix(y, y_pred))
print('Relatario classificao', classification_report(y, y_pred))
# Out:
# Acuracia 0.7
# Matriz confusion [[ 1  0  2]
#  [ 0  2  2]
#  [ 1  1 11]]
# Relatario classificao               precision    recall  f1-score   support
#
#       setosa       0.50      0.33      0.40         3
#   versicolor       0.67      0.50      0.57         4
#    virginica       0.73      0.85      0.79        13
#
#     accuracy                           0.70        20
#    macro avg       0.63      0.56      0.59        20
# weighted avg       0.68      0.70      0.68        20

# %%
# x1 =[round(random.uniform(0, 8), 1) for i in range(20)]
# x2 = [round(random.uniform(0, 8), 1) for i in range(20)]
# c = 0
# for i in x2:
#   #
#   nova_amostra[c].append([i])
#   c += 1

# %%
nova_amostra = [[4.8, 4.4],
 [7.9, 0.6],
 [4.4, 3.1],
 [1.7, 4.6],
 [4.4, 3.4],
 [1.6, 2.4],
 [5.1, 7.1],
 [2.5, 5.2],
 [7.6, 7.9],
 [1.4, 5.0],
 [4.8, 4.0],
 [3.5, 4.3],
 [1.3, 0.3],
 [2.9, 7.7],
 [5.6, 7.9],
 [2.9, 3.8],
 [3.1, 1.8],
 [4.7, 5.2],
 [3.2, 1.2],
 [5.0, 6.3]]
